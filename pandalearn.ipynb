# %% [markdown]
# Dataframes

# %%
import pandas as pd

df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns=["A", "B", "C"], index=["X", "Y", "Z"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, X to Z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df.nunique()
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df.size
# Out:
# 9

# %%
df['A'].unique()
# Out:
# array([1, 4, 7])

# %%
df.index
# Out:
# Index(['X', 'Y', 'Z'], dtype='object')

# %%
df.index.tolist()
# Out:
# ['X', 'Y', 'Z']

# %%
df.head()
# Out:
#    A  B  C
# X  1  2  3
# Y  4  5  6
# Z  7  8  9

# %%
df.tail(2) # in this "tail" function 2 represents printing bottom 2 rows
# Out:
#    A  B  C
# Y  4  5  6
# Z  7  8  9

# %%
df.columns.tolist()
# Out:
# ['A', 'B', 'C']

# %%
df.shape
# Out:
# (3, 3)

# %% [markdown]
# Loading Dataframes from Files

# %%
coffee = pd.read_csv('./warmup-data/coffee.csv')

# %%
print(coffee)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
results = pd.read_parquet('./data/results.parquet')

# %%
results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %%
olympics_data = pd.read_excel('./data/olympics-data.xlsx', sheet_name="results")

# %%
olympics_data.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN

# %%
bios = pd.read_csv('./data/bios.csv')

# %%
bios.to_excel
# Out:
# <bound method NDFrame.to_excel of         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %% [markdown]
# Accessing Data using Pandas

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
display(coffee)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.head(10)
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25
# 6   Thursday    Espresso          40
# 7   Thursday       Latte          30
# 8     Friday    Espresso          45
# 9     Friday       Latte          35

# %%
coffee.tail(6)
# Out:
#          Day Coffee Type  Units Sold
# 8     Friday    Espresso          45
# 9     Friday       Latte          35
# 10  Saturday    Espresso          45
# 11  Saturday       Latte          35
# 12    Sunday    Espresso          45
# 13    Sunday       Latte          35

# %%
coffee.sample(10, random_state=1)
# Out:
#           Day Coffee Type  Units Sold
# 3     Tuesday       Latte          20
# 7    Thursday       Latte          30
# 6    Thursday    Espresso          40
# 2     Tuesday    Espresso          30
# 10   Saturday    Espresso          45
# 4   Wednesday    Espresso          35
# 1      Monday       Latte          15
# 12     Sunday    Espresso          45
# 0      Monday    Espresso          25
# 13     Sunday       Latte          35

# %%
coffee.loc[5:9, ["Day","Units Sold"]]
# .loc[#rows,#columns] is used to print specific row/column or both row and column
# [x:] this means x onwards, and if there is another number after semicolon ":" it means x to other number
# we can also print specified columns by adding there name
# Out:
#          Day  Units Sold
# 5  Wednesday          25
# 6   Thursday          40
# 7   Thursday          30
# 8     Friday          45
# 9     Friday          35

# %%
coffee.iloc[5:9, [0,2]]

# notice the difference in slicing "loc" is inclusive of slicing where as "iloc" is exclusive
# also in "loc" we have to name the column entry but in "iloc" we have to type row number
# Out:
#          Day  Units Sold
# 5  Wednesday          25
# 6   Thursday          40
# 7   Thursday          30
# 8     Friday          45

# %%
# coffee.index = coffee.Day
# code hashed for future
# or we can also use coffee.index = coffee["Day"]
# this line of code changed the index that was numerical to the days.

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.loc["Monday":"Wednesday"]
# thus indexing the data wrt days helped to sort/find the coffee sold on particular day7 or period acc. to days (or any which is indexed)
# in this case it shows the coffee sales from monday to wednesday
# Out:
# Empty DataFrame
# Columns: [Day, Coffee Type, Units Sold]
# Index: []

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.loc[1:3, "Units Sold"] = 10
# incase we are using index as day names so use "day_name" instead of 1

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          10
# 2    Tuesday    Espresso          10
# 3    Tuesday       Latte          10
# 4  Wednesday    Espresso          35

# %%
coffee.at[1, "Units Sold"]
# Out:
# np.int64(10)

# %%
coffee.iat[1, 2]
# Out:
# np.int64(10)

# %%
coffee.loc[1, "Units Sold"]
# Out:
# np.int64(10)

# %%
coffee.iloc[1:3, 2]
# Out:
# 1    10
# 2    10
# Name: Units Sold, dtype: int64

# %%
# at/ iat cant slice but are fast
# but loc/iloc can slice but are slower
# ie no multiple data line output

# %%
coffee["Day"]
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
coffee.sort_values(["Units Sold", "Coffee Type", "Day"], ascending=[0,1,0])
# Out:
#           Day Coffee Type  Units Sold
# 12     Sunday    Espresso          45
# 10   Saturday    Espresso          45
# 8      Friday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 13     Sunday       Latte          35
# 11   Saturday       Latte          35
# 9      Friday       Latte          35
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          10
# 3     Tuesday       Latte          10
# 1      Monday       Latte          10

# %%
for index, row in coffee.iterrows():
    print(index)
    print(row['Units Sold'])
    print("\n\n\n\n")
# Out:
# 0
# 25
#
#
#
#
#
# 1
# 10
#
#
#
#
#
# 2
# 10
#
#
#
#
#
# 3
# 10
#
#
#
#
#
# 4
# 35
#
#
#
#
#
# 5
# 25
#
#
#
#
#
# 6
# 40
#
#
#
#
#
# 7
# 30
#
#
#
#
#
# 8
# 45
#
#
#
#
#
# 9
# 35
#
#
#
#
#
# 10
# 45
#
#
#
#
#
# 11
# 35
#
#
#
#
#
# 12
# 45
#
#
#
#
#
# 13
# 35

# %% [markdown]
# Filtering Data

# %%
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
tall_lads = bios.loc[bios['height_cm'] >= 215, ['name', 'height_cm']]
tall_lads
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5599        Vladimir Andreyev      215.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7056                 Shan Tao      215.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7298              Wang Zhizhi      215.0
# 7376      Eurelijus Žukauskas      218.0
# 52520            Marcin Nowak      215.0
# ...

# %%
tall_lads.sort_values(["height_cm"], ascending = [1])
# Out:
#                          name  height_cm
# 5599        Vladimir Andreyev      215.0
# 7056                 Shan Tao      215.0
# 112327      Patrick Femerling      215.0
# 107369              Pau Gasol      215.0
# 82105            Gregor Fucka      215.0
# 52604      Stanislav Dineykin      215.0
# 52520            Marcin Nowak      215.0
# 7298              Wang Zhizhi      215.0
# 131058            Rudy Gobert      215.0
# 141018          Yuta Watanabe      215.0
# 112358     Aleksey Savrasenko      215.0
# 112330      Ioannis Bourousis      215.0
# 6409         Sergey Kovalenko      216.0
# 6722         Shaquille O'Neal      216.0
# 6270              Hu Zhangbao      216.0
# 6223              Lars Hansen      216.0
# 118663         Timofey Mozgov      216.0
# 112332    Andreas Glyniadakis      216.0
# 138671          Ondřej Balvín      216.0
# 121694            Salah Mejri      216.0
# 6937           David Robinson      216.0
# 123850         Tyson Chandler      216.0
# ...

# %%
print(bios['born_country'].unique())
# showing country code
# Out:
# ['FRA' 'GBR' nan 'MAR' 'FPN' 'IRQ' 'USA' 'RSA' 'IRL' 'IND' 'CHN' 'JAM'
#  'AUS' 'CAN' 'GER' 'ROU' 'BRA' 'CZE' 'RUS' 'GRE' 'EGY' 'HUN' 'POL' 'MEX'
#  'SRB' 'SVK' 'INA' 'SRI' 'PAK' 'ESP' 'AUT' 'BEL' 'BLR' 'BUL' 'CRC' 'DEN'
#  'EST' 'FIN' 'SUI' 'GEO' 'ARG' 'ARM' 'BAH' 'CAM' 'CHI' 'ISR' 'UZB' 'ITA'
#  'JPN' 'KOR' 'LAT' 'UKR' 'LTU' 'LUX' 'MAD' 'MAS' 'MRI' 'NED' 'NGR' 'NOR'
#  'TUR' 'NZL' 'PAR' 'PER' 'BAR' 'HKG' 'GUY' 'CGO' 'COD' 'CMR' 'COL' 'PUR'
#  'TPE' 'VIE' 'CUB' 'DOM' 'CRO' 'ECU' 'ESA' 'MDA' 'MGL' 'ZIM' 'PHI' 'POR'
#  'SLO' 'SWE' 'TJK' 'CIV' 'BIH' 'THA' 'CAF' 'ALG' 'PRK' 'KAZ' 'UGA' 'TTO'
#  'TUN' 'AZE' 'URU' 'MYA' 'VEN' 'ETH' 'FIJ' 'SEN' 'LBA' 'GAB' 'NCA' 'CUR'
#  'ARU' 'ANG' 'Cologne' 'KOS' 'GHA' 'GUA' 'TLS' 'NEP' 'IRI' 'KEN' 'KGZ'
#  'LBR' 'MAW' 'MLI' 'NAM' 'CPV' 'SUR' 'SLE' 'NIG' 'PAN' 'SAM' 'TKM' 'MKD'
#  'SGP' 'MNE' 'SYR' 'MON' 'PNG' 'BEN' 'ZAM' 'SUD' 'SSD' 'BDI' 'TAN' 'VAN'
#  'BOL' 'MLT' 'JER' 'KSA' 'MOZ' 'BER' 'GRL' 'LBN' 'CYP' 'SMR' 'ERI' 'LIE'
# ...

# %%
bios[(bios['height_cm'] >= 215) & (bios['born_country'] == 'FRA')]
# Out:
#         athlete_id            name   born_date      born_city born_region  \
# 82100        82753   Frédéric Weis  1977-06-22     Thionville     Moselle
# 131058      133820     Rudy Gobert  1992-06-26  Saint-Quentin       Aisne
# 139365      142836  Moustapha Fall  1992-02-23          Paris       Paris
#
#        born_country     NOC  height_cm  weight_kg died_date
# 82100           FRA  France      218.0      110.0       NaN
# 131058          FRA  France      215.0      113.0       NaN
# 139365          FRA  France      218.0        NaN       NaN

# %%
bios[bios['name'].str.contains("Ojas|gupta", case=0)]
# Out:
#         athlete_id                       name   born_date  \
# 1617          1624             Clemente Rojas  1952-09-01
# 1670          1677               Freddy Rojas  1969-08-27
# 1671          1678              Ricardo Rojas  1955-06-15
# 1993          2003              Ricardo Rojas  1959-04-04
# 6664          6697           Jorge Moré Rojas  1958-05-09
# 6949          6984              Joaquín Rojas  1938-07-06
# 6950          6985             Fernando Rojas  1921-08-02
# 6951          6986                 José Rojas  1923-11-09
# 10256        10312               Sandra Rojas  1973-10-20
# 24378        24567               Marcos Rojas  1952-11-08
# 36038        36323            Alejandro Rojas  1962-01-06
# 36039        36324              Marcelo Rojas  1963-04-23
# 46235        46582                Ilmar Ojase  1973-07-06
# 58373        58789  Mohamed Ali Khojastehpour  1931-07-01
# 73008        73569               Genaro Rojas  1970-09-15
# ...

# %%
    # THESE ARE SOME COMMONLY USED REGEX's
    # "headings":          df[df['notes'].str.contains(r'^#{1,6} ', regex=True)],
    # "bullet_points":     df[df['notes'].str.contains(r'^[-*+] ', regex=True)],
    # "numbered_lists":    df[df['notes'].str.contains(r'^\d+\. ', regex=True)],
    # "todo_unchecked":    df[df['notes'].str.contains(r'^- \[ \] ', regex=True)],
    # "todo_checked":      df[df['notes'].str.contains(r'^- \[x\] ', regex=True)],
    # "iso_dates":         df[df['notes'].str.contains(r'\b\d{4}-\d{2}-\d{2}\b', regex=True)],
    # "flexible_dates":    df[df['notes'].str.contains(r'\b(?:\d{1,2}[/-]){2}\d{2,4}\b', regex=True)],
    # "times":             df[df['notes'].str.contains(r'\b\d{1,2}:\d{2}(?: ?[APMapm]{2})?\b', regex=True)],
    # "tags":              df[df['notes'].str.contains(r'#\w+', regex=True)],
    # "mentions":          df[df['notes'].str.contains(r'@\w+', regex=True)],
    # "inline_code":       df[df['notes'].str.contains(r'`[^`]+`', regex=True)],
    # "fenced_code":       df[df['notes'].str.contains(r'```[\s\S]*?```', regex=True)],
    # "priority_flags":    df[df['notes'].str.contains(r'!!+', regex=True)]
    # USE regex = false to turn of its capability

# %%
bios[(bios['born_country'].isin(["USA", "IND", "GBR"])) & (bios['name'].str.startswith("Ojas"))]
# Out:
# Empty DataFrame
# Columns: [athlete_id, name, born_date, born_city, born_region, born_country, NOC, height_cm, weight_kg, died_date]
# Index: []

# %%
bios.query('born_country == "USA" & born_city == "Burlingame"')
# Out:
#         athlete_id             name   born_date   born_city born_region  \
# 54              55    Monique Javer  1967-07-22  Burlingame  California
# 2719          2731        Diana Gee  1968-12-21  Burlingame  California
# 40145        40453  Catriona Fallon  1970-08-08  Burlingame  California
# 77768        78359      Ben Eastman  1911-07-09  Burlingame  California
# 87182        87878   Duncan Kennedy  1967-12-20  Burlingame  California
# 107963      109104  Chloe Kloezeman  1986-05-29  Burlingame  California
#
#        born_country            NOC  height_cm  weight_kg   died_date
# 54              USA  Great Britain      177.0       64.0         NaN
# 2719            USA  United States      162.0       45.0         NaN
# 40145           USA  United States      185.0       77.0         NaN
# 77768           USA  United States      185.0       70.0  2002-10-06
# 87182           USA  United States      180.0       77.0         NaN
# ...

# %% [markdown]
# Adding/Removing Columns

# %% [markdown]
# 1) Basics

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          10
# 3     Tuesday       Latte          10
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee
coffee['price'] = 499

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price
# 0      Monday    Espresso          25    499
# 1      Monday       Latte          10    499
# 2     Tuesday    Espresso          10    499
# 3     Tuesday       Latte          10    499
# 4   Wednesday    Espresso          35    499
# 5   Wednesday       Latte          25    499
# 6    Thursday    Espresso          40    499
# 7    Thursday       Latte          30    499
# 8      Friday    Espresso          45    499
# 9      Friday       Latte          35    499
# 10   Saturday    Espresso          45    499
# 11   Saturday       Latte          35    499
# 12     Sunday    Espresso          45    499
# 13     Sunday       Latte          35    499

# %%
import numpy as np

coffee['new price'] = np.where(coffee['Coffee Type']=='Espresso',399, 499)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  new price
# 0      Monday    Espresso          25    499        399
# 1      Monday       Latte          10    499        499
# 2     Tuesday    Espresso          10    499        399
# 3     Tuesday       Latte          10    499        499
# 4   Wednesday    Espresso          35    499        399
# 5   Wednesday       Latte          25    499        499
# 6    Thursday    Espresso          40    499        399
# 7    Thursday       Latte          30    499        499
# 8      Friday    Espresso          45    499        399
# 9      Friday       Latte          35    499        499
# 10   Saturday    Espresso          45    499        399
# 11   Saturday       Latte          35    499        499
# 12     Sunday    Espresso          45    499        399
# 13     Sunday       Latte          35    499        499

# %%
coffee.drop(0)
# Out:
#           Day Coffee Type  Units Sold  price  new price
# 1      Monday       Latte          10    499        499
# 2     Tuesday    Espresso          10    499        399
# 3     Tuesday       Latte          10    499        499
# 4   Wednesday    Espresso          35    499        399
# 5   Wednesday       Latte          25    499        499
# 6    Thursday    Espresso          40    499        399
# 7    Thursday       Latte          30    499        499
# 8      Friday    Espresso          45    499        399
# 9      Friday       Latte          35    499        499
# 10   Saturday    Espresso          45    499        399
# 11   Saturday       Latte          35    499        499
# 12     Sunday    Espresso          45    499        399
# 13     Sunday       Latte          35    499        499

# %%
#coffee.drop(columns=['price'], inplace=True) # removes the column
coffee
# Out:
#           Day Coffee Type  Units Sold  price  new price
# 0      Monday    Espresso          25    499        399
# 1      Monday       Latte          10    499        499
# 2     Tuesday    Espresso          10    499        399
# 3     Tuesday       Latte          10    499        499
# 4   Wednesday    Espresso          35    499        399
# 5   Wednesday       Latte          25    499        499
# 6    Thursday    Espresso          40    499        399
# 7    Thursday       Latte          30    499        499
# 8      Friday    Espresso          45    499        399
# 9      Friday       Latte          35    499        499
# 10   Saturday    Espresso          45    499        399
# 11   Saturday       Latte          35    499        499
# 12     Sunday    Espresso          45    499        399
# 13     Sunday       Latte          35    499        499

# %%
coffee['revenue'] = coffee['Units Sold'] * coffee['new price']
coffee
# Out:
#           Day Coffee Type  Units Sold  price  new price  revenue
# 0      Monday    Espresso          25    499        399     9975
# 1      Monday       Latte          10    499        499     4990
# 2     Tuesday    Espresso          10    499        399     3990
# 3     Tuesday       Latte          10    499        499     4990
# 4   Wednesday    Espresso          35    499        399    13965
# 5   Wednesday       Latte          25    499        499    12475
# 6    Thursday    Espresso          40    499        399    15960
# 7    Thursday       Latte          30    499        499    14970
# 8      Friday    Espresso          45    499        399    17955
# 9      Friday       Latte          35    499        499    17465
# 10   Saturday    Espresso          45    499        399    17955
# 11   Saturday       Latte          35    499        499    17465
# 12     Sunday    Espresso          45    499        399    17955
# ...

# %%
coffee = coffee.drop(columns=['price'])

# %%
#coffee = coffee.rename(columns={'new price':'price'})
# renames the column

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new price  revenue
# 0      Monday    Espresso          25        399     9975
# 1      Monday       Latte          10        499     4990
# 2     Tuesday    Espresso          10        399     3990
# 3     Tuesday       Latte          10        499     4990
# 4   Wednesday    Espresso          35        399    13965
# 5   Wednesday       Latte          25        499    12475
# 6    Thursday    Espresso          40        399    15960
# 7    Thursday       Latte          30        499    14970
# 8      Friday    Espresso          45        399    17955
# 9      Friday       Latte          35        499    17465
# 10   Saturday    Espresso          45        399    17955
# 11   Saturday       Latte          35        499    17465
# 12     Sunday    Espresso          45        399    17955
# 13     Sunday       Latte          35        499    17465

# %% [markdown]
# 2) String Operations, Datetime Operation etc..

# %%
bios_new = bios.copy()

# %%
bios_new['first name'] = bios_new['name'].str.split(' ').str[0]

# %%
bios_new.query('`first name` == "Novak"')
# Out:
#         athlete_id             name   born_date           born_city  \
# 27759        27967  Novak Roganović  1932-01-14               Senta
# 116190      117575    Novak Đoković  1987-05-22  Beograd (Belgrade)
#
#           born_region born_country         NOC  height_cm  weight_kg  \
# 27759   Severni Banat          SRB  Yugoslavia      171.0       69.0
# 116190        Beograd          SRB      Serbia      188.0       80.0
#
#          died_date first name
# 27759   2009-02-04      Novak
# 116190         NaN      Novak

# %%
bios_new['born_date'] = pd.to_datetime(bios_new['born_date'], errors='coerce')
#bios_new['born_date'] = bios_new['born_date'].dt.strftime('%d-%m-%Y')
bios_new.info()
bios_new
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   athlete_id         145500 non-null  int64
#  1   name               145500 non-null  object
#  2   born_date          143693 non-null  datetime64[ns]
#  3   born_city          110908 non-null  object
#  4   born_region        110908 non-null  object
#  5   born_country       110908 non-null  object
#  6   NOC_x              145499 non-null  object
#  7   height_cm          106651 non-null  float64
#  8   weight_kg          102070 non-null  float64
#  9   died_date          33940 non-null   object
#  10  height_category    145500 non-null  object
#  11  Category           145500 non-null  object
#  12  NOC_y              110639 non-null  object
#  13  born_country_full  110636 non-null  object
#  14  notes              257 non-null     object
# ...

# %%
print(bios_new['born_date'].head())
print(bios_new['born_date'].dtype)
# Out:
# 0   1886-12-12
# 1   1969-04-01
# 2   1898-08-13
# 3   1895-05-11
# 4   1878-04-17
# Name: born_date, dtype: datetime64[ns]
# datetime64[ns]

# %%
bios_new.query('`first name` == "Novak"')[['name', 'born_date']]
# Out:
#                    name  born_date
# 27759   Novak Roganović 1932-01-14
# 116190    Novak Đoković 1987-05-22

# %%
bios_new.to_csv('./data/bios_new.csv', index=False)

# %%
bios['height_category'] = bios['height_cm'].apply(lambda x:'Short' if x < 165 else ('Average' if x < 185 else 'Tall'))
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
def categories_athlete(row):
    if row['height_cm'] < 175 and row['weight_kg'] < 70:
        return 'Lightweight'
    elif row['height_cm'] < 185 and row['weight_kg'] <= 80:
        return 'midweight'
    else:
        return 'heavyweight'  

bios['Category'] = bios.apply(categories_athlete, axis=1)
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category     Category
# 0  1960-10-02            Tall  heavyweight
# 1         NaN         Average    midweight
# 2  1994-07-17         Average    midweight
# ...

# %%
nocs = pd.read_csv('./data/noc_regions.csv')

# %%
bios_new = pd.merge(bios, nocs, left_on='born_country', right_on='NOC', how='left')#, suffixes=("bios_new", "an"))

# %%
bios_new.rename(columns={'region': 'born_country_full'}, inplace=True)
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country      NOC_x  height_cm  weight_kg  \
# ...

# %%
bios_new[bios_new['NOC_x'] != bios_new['born_country_full']][['name', 'NOC_x', 'born_country_full']]
# Out:
#                        name    NOC_x born_country_full
# 4              Albert Canet   France                UK
# 12                J. Defert   France               NaN
# 13           Étienne Durand   France               NaN
# 16               Guy Forget   France           Morocco
# 27       Guy, Baron Lejeune   France               NaN
# ...                     ...      ...               ...
# 145491        Matthew Wepke  Jamaica               NaN
# 145493   Landysh Falyakhova      ROC            Russia
# 145495    Polina Luchnikova      ROC            Russia
# 145496  Valeriya Merkusheva      ROC            Russia
# 145497      Yuliya Smirnova      ROC            Russia
#
# [73210 rows x 3 columns]

# %%
usa = bios[bios['born_country']=='USA'].copy()
gbr = bios[bios['born_country']=='GBR'].copy()

# %%
#n_df = bios[bios['born_country'].isin(['GBR', 'USA'])].copy() # cant filter using this
n_df = pd.concat([usa, gbr])

# %%
n_df.tail()
# Out:
#         athlete_id                name   born_date     born_city born_region  \
# 144811      148512  Benjamin Alexander  1983-05-08        London     England
# 144815      148517       Ashley Watson  1993-10-28  Peterborough     England
# 145005      148716     Peder Kongshaug  2001-08-13     Wimbledon     England
# 145319      149041          Axel Brown  1992-04-02     Harrogate     England
# 145388      149111      Jean-Luc Baker  1993-10-07       Burnley     England
#
#        born_country                  NOC  height_cm  weight_kg died_date  \
# 144811          GBR              Jamaica        NaN        NaN       NaN
# 144815          GBR              Jamaica        NaN        NaN       NaN
# 145005          GBR               Norway      184.0       86.0       NaN
# 145319          GBR  Trinidad and Tobago        NaN        NaN       NaN
# 145388          GBR        United States        NaN        NaN       NaN
#
#        height_category     Category
# ...

# %%
results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %%
combined_df = pd.merge(results, bios, on='athlete_id', how='left')

# %%
combined_df
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                    None        Slalom, Women (Olympic)
#
# ...

# %% [markdown]
# Handling Null values (NaN)

# %%
coffee.loc[[0,1], 'Units Sold'] = np.nan

# %%
coffee.fillna(coffee['Units Sold'].mean())
# we can use .interpolate() instead of .mean() 
# Use .mean() when you want a quick, general fix for missing values.
# Use .interpolate() when your data has sequence or trends and you want to preserve that structure.
# Out:
#           Day Coffee Type  Units Sold  new price  revenue
# 0      Monday    Espresso        32.5        399     9975
# 1      Monday       Latte        32.5        499     4990
# 2     Tuesday    Espresso        10.0        399     3990
# 3     Tuesday       Latte        10.0        499     4990
# 4   Wednesday    Espresso        35.0        399    13965
# 5   Wednesday       Latte        25.0        499    12475
# 6    Thursday    Espresso        40.0        399    15960
# 7    Thursday       Latte        30.0        499    14970
# 8      Friday    Espresso        45.0        399    17955
# 9      Friday       Latte        35.0        499    17465
# 10   Saturday    Espresso        45.0        399    17955
# 11   Saturday       Latte        35.0        499    17465
# 12     Sunday    Espresso        45.0        399    17955
# 13     Sunday       Latte        35.0        499    17465

# %%
coffee[coffee['Units Sold'].notna()]
# shows rows which do not contains NaN rows
# Out:
#           Day Coffee Type  Units Sold  new price  revenue
# 2     Tuesday    Espresso        10.0        399     3990
# 3     Tuesday       Latte        10.0        499     4990
# 4   Wednesday    Espresso        35.0        399    13965
# 5   Wednesday       Latte        25.0        499    12475
# 6    Thursday    Espresso        40.0        399    15960
# 7    Thursday       Latte        30.0        499    14970
# 8      Friday    Espresso        45.0        399    17955
# 9      Friday       Latte        35.0        499    17465
# 10   Saturday    Espresso        45.0        399    17955
# 11   Saturday       Latte        35.0        499    17465
# 12     Sunday    Espresso        45.0        399    17955
# 13     Sunday       Latte        35.0        499    17465

# %% [markdown]
# Aggregating Data

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category     Category
# 0  1960-10-02            Tall  heavyweight
# 1         NaN         Average    midweight
# 2  1994-07-17         Average    midweight
# ...

# %%
bios[bios['born_country']=='IND']['born_region'].value_counts()
# Out:
# born_region
# Punjab                                 94
# Maharashtra                            56
# West Bengal                            49
# Haryana                                43
# Uttar Pradesh                          42
# Tamil Nadu                             34
# Karnataka                              32
# National Capital Territory of Delhi    32
# Kerala                                 26
# Andhra Pradesh                         23
# Madhya Pradesh                         22
# Rajasthan                              14
# Himachal Pradesh                       10
# Manipur                                10
# Gujarat                                 9
# Bihar                                   6
# Assam                                   5
# Jharkhand                               5
# Jammu and Kashmir                       5
# Uttarakhand                             4
# Tripura                                 3
# Nagaland                                2
# ...

# %%
coffee.groupby(['Coffee Type'])['Units Sold'].mean()
# Out:
# Coffee Type
# Espresso    36.666667
# Latte       28.333333
# Name: Units Sold, dtype: float64

# %%
coffee.groupby(['Coffee Type']).agg({'Units Sold': 'sum', 'new price': 'mean'})
# Out:
#              Units Sold  new price
# Coffee Type
# Espresso          220.0      399.0
# Latte             170.0      499.0

# %%
pivot = coffee.pivot(columns='Coffee Type', index='Day', values='revenue')

# %%
pivot.sum(axis = 1)
# Out:
# Day
# Friday       35420
# Monday       14965
# Saturday     35420
# Sunday       35420
# Thursday     30930
# Tuesday       8980
# Wednesday    26440
# dtype: int64

# %%
bios_new['born_date'] = pd.to_datetime(bios_new['born_date'])
bios_new['month_born'] = bios_new['born_date'].dt.month
bios_new['year_born'] = bios_new['born_date'].dt.year
bios_new.groupby([bios_new['year_born'],bios_new['month_born']])['name'].count().reset_index().sort_values('name', ascending=False)
# Out:
#       year_born  month_born  name
# 1437     1970.0         1.0   239
# 1461     1972.0         1.0   229
# 1497     1975.0         1.0   227
# 1629     1986.0         1.0   227
# 1617     1985.0         1.0   225
# ...         ...         ...   ...
# 1877     2006.0        12.0     1
# 1871     2006.0         3.0     1
# 20       1846.0         7.0     1
# 21       1846.0         8.0     1
# 22       1846.0         9.0     1
#
# [1885 rows x 3 columns]

# %% [markdown]
# Advanced Functionality

# %%
coffee['yesterday_revenue'] = coffee['revenue'].shift()
coffee['percent_change'] = coffee['revenue']/coffee['yesterday_revenue'] * 100
coffee
# Out:
#           Day Coffee Type  Units Sold  new price  revenue  yesterday_revenue  \
# 0      Monday    Espresso         NaN        399     9975                NaN
# 1      Monday       Latte         NaN        499     4990             9975.0
# 2     Tuesday    Espresso        10.0        399     3990             4990.0
# 3     Tuesday       Latte        10.0        499     4990             3990.0
# 4   Wednesday    Espresso        35.0        399    13965             4990.0
# 5   Wednesday       Latte        25.0        499    12475            13965.0
# 6    Thursday    Espresso        40.0        399    15960            12475.0
# 7    Thursday       Latte        30.0        499    14970            15960.0
# 8      Friday    Espresso        45.0        399    17955            14970.0
# 9      Friday       Latte        35.0        499    17465            17955.0
# 10   Saturday    Espresso        45.0        399    17955            17465.0
# ...

# %%
bios['height_rank'] = bios['height_cm'].rank(ascending=False)

# %%
bios.sort_values(['height_rank']).sample(10)[['name', 'height_rank']]
# Out:
#                       name  height_rank
# 116871       José Aceituno      87188.5
# 128113          Andi Murez      24214.0
# 23285          Péter Vánky       9882.0
# 104027  Clementine Béwouda      62600.5
# 4249    Kanemaru Shiratori      91849.5
# 125168       Mitchel Malyk      24214.0
# 109210       Jörg Dallmann      81027.5
# 75055         Alenka Bikar      98114.5
# 140759    Mohammad Al-Wadi          NaN
# 100614      Philipp Schoch      27597.5

# %%
coffee['cumulative_revenue']=coffee['revenue'].cumsum()
coffee
# Out:
#           Day Coffee Type  Units Sold  new price  revenue  yesterday_revenue  \
# 0      Monday    Espresso         NaN        399     9975                NaN
# 1      Monday       Latte         NaN        499     4990             9975.0
# 2     Tuesday    Espresso        10.0        399     3990             4990.0
# 3     Tuesday       Latte        10.0        499     4990             3990.0
# 4   Wednesday    Espresso        35.0        399    13965             4990.0
# 5   Wednesday       Latte        25.0        499    12475            13965.0
# 6    Thursday    Espresso        40.0        399    15960            12475.0
# 7    Thursday       Latte        30.0        499    14970            15960.0
# 8      Friday    Espresso        45.0        399    17955            14970.0
# 9      Friday       Latte        35.0        499    17465            17955.0
# 10   Saturday    Espresso        45.0        399    17955            17465.0
# ...

# %%
latte = coffee[coffee['Coffee Type']=="Latte"].copy()
latte['day3'] = latte['Units Sold'].rolling(3).sum()
latte
# Out:
#           Day Coffee Type  Units Sold  new price  revenue  yesterday_revenue  \
# 1      Monday       Latte         NaN        499     4990             9975.0
# 3     Tuesday       Latte        10.0        499     4990             3990.0
# 5   Wednesday       Latte        25.0        499    12475            13965.0
# 7    Thursday       Latte        30.0        499    14970            15960.0
# 9      Friday       Latte        35.0        499    17465            17955.0
# 11   Saturday       Latte        35.0        499    17465            17955.0
# 13     Sunday       Latte        35.0        499    17465            17955.0
#
#     percent_change  cumulative_revenue   day3
# 1        50.025063               14965    NaN
# 3       125.062657               23945    NaN
# 5        89.330469               50385    NaN
# 7        93.796992               81315   65.0
# 9        97.270955              116735   90.0
# 11       97.270955              152155  100.0
# ...

# %% [markdown]
# New Functionality

# %%
results_numpy = pd.read_csv('./data/results.csv')
results_arrow = pd.read_csv('./data/results.csv', engine='pyarrow', dtype_backend='pyarrow')

# %%
results_numpy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308408 entries, 0 to 308407
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   year        305807 non-null  float64
#  1   type        305807 non-null  object
#  2   discipline  308407 non-null  object
#  3   event       308408 non-null  object
#  4   as          308408 non-null  object
#  5   athlete_id  308408 non-null  int64
#  6   noc         308407 non-null  object
#  7   team        121714 non-null  object
#  8   place       283193 non-null  float64
#  9   tied        308408 non-null  bool
#  10  medal       44139 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(7)
# memory usage: 23.8+ MB

# %%
results_arrow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308408 entries, 0 to 308407
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   year        305807 non-null  double[pyarrow]
#  1   type        305807 non-null  string[pyarrow]
#  2   discipline  308407 non-null  string[pyarrow]
#  3   event       308408 non-null  string[pyarrow]
#  4   as          308408 non-null  string[pyarrow]
#  5   athlete_id  308408 non-null  int64[pyarrow]
#  6   noc         308407 non-null  string[pyarrow]
#  7   team        121714 non-null  string[pyarrow]
#  8   place       283193 non-null  double[pyarrow]
#  9   tied        308408 non-null  bool[pyarrow]
#  10  medal       44139 non-null   string[pyarrow]
# dtypes: bool[pyarrow](1), double[pyarrow](2), int64[pyarrow](1), string[pyarrow](7)
# memory usage: 37.5 MB

# %%
results_numpy["as"].str.contains("Ojas")
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 308403    False
# 308404    False
# 308405    False
# 308406    False
# 308407    False
# Name: as, Length: 308408, dtype: bool

# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.10.3-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached contourpy-1.3.2-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.58.4-cp312-cp312-win_amd64.whl.metadata (108 kB)
# ...
#   Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# ...
#   Using cached pillow-11.2.1-cp312-cp312-win_amd64.whl.metadata (9.1 kB)
# ...
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# ...
# Using cached matplotlib-3.10.3-cp312-cp312-win_amd64.whl (8.1 MB)
# Using cached contourpy-1.3.2-cp312-cp312-win_amd64.whl (223 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.58.4-cp312-cp312-win_amd64.whl (2.2 MB)
# Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl (71 kB)
# Using cached pillow-11.2.1-cp312-cp312-win_amd64.whl (2.7 MB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# ...
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'bios' and already loaded

# Filter out rows where the 'height_cm' data is missing
bios_filtered = bios[bios['height_cm'].notnull()]

# Plotting the histogram
plt.figure(figsize=(10, 6))
plt.hist(bios_filtered['height_cm'], bins=20, color='blue', edgecolor='black')
plt.title('Distribution of Athlete Heights in Olympics')
plt.xlabel('Height in cm')
plt.ylabel('Number of Athletes')
plt.grid(True)

# Use a logarithmic scale for the y-axis if the data spread is wide
plt.yscale('log')

# Display the plot
plt.show()
